# %% [markdown]
# <a href="https://colab.research.google.com/github/caleb-stewart/Trademark-Analysis-Identification-Tool/blob/main/video_trait.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install ultralytics
# !pip install pillow
# !pip install faiss-cpu

# %%
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as tr
import cv2
import faiss
import numpy as np
from PIL import Image
from transformers import CLIPProcessor, CLIPModel, BeitFeatureExtractor, BeitModel
from torchvision.models.feature_extraction import create_feature_extractor
from ultralytics import YOLO
import os
from collections import defaultdict

# %%
class EmbeddingExtractor:
    """Class for extracting image embeddings using ResNet-50, CLIP, and BEiT."""

    def __init__(self, device=None):
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'

        # Load ResNet-50 model
        self.resnet = torchvision.models.resnet50(pretrained=True)
        self.resnet.fc = nn.Identity()
        self.resnet = self.resnet.to(self.device).eval()

        # Load CLIP model
        self.clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(self.device).eval()
        self.clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

        # Load BEiT model
        self.beit_model = BeitModel.from_pretrained("microsoft/beit-base-patch16-224").to(self.device).eval()
        self.beit_processor = BeitFeatureExtractor.from_pretrained("microsoft/beit-base-patch16-224")

    def preprocess_resnet(self, img):
        transformations = tr.Compose([
            tr.Resize((224, 224)),
            tr.ToTensor(),
            tr.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
        img = transformations(img).unsqueeze(0).to(self.device)
        return img

    def preprocess_clip(self, img):
        return self.clip_processor(images=img, return_tensors="pt")["pixel_values"].to(self.device)

    def preprocess_beit(self, img):
        return self.beit_processor(images=img, return_tensors="pt")["pixel_values"].to(self.device)

    def get_embedding(self, img, model_name="resnet"):

        img = Image.fromarray(img)

        if model_name == "resnet":
            img_tensor = self.preprocess_resnet(img)
            with torch.no_grad():
                embedding = self.resnet(img_tensor).cpu().numpy()

        elif model_name == "clip":
            img_tensor = self.preprocess_clip(img)
            with torch.no_grad():
                embedding = self.clip_model.get_image_features(img_tensor).cpu().numpy()

        elif model_name == "beit":
            img_tensor = self.preprocess_beit(img)
            with torch.no_grad():
                embedding = self.beit_model(img_tensor).last_hidden_state.mean(dim=1).cpu().numpy()

        else:
            raise ValueError("Invalid model name. Choose from: resnet, clip, beit.")

        return embedding

    @staticmethod
    def cosine_similarity(emb1, emb2):

        return torch.nn.functional.cosine_similarity(torch.tensor(emb1), torch.tensor(emb2)).item()

    @staticmethod
    def euclidean_distance(emb1, emb2):

        return np.linalg.norm(emb1 - emb2)

# %%
model = YOLO("best.pt")
embed_extract = EmbeddingExtractor()

# %%
def extract_logo_regions(image, save_crop=False, output_dir="cropped_logos"):
    """Runs YOLO on an image and extracts detected logo regions."""

    # Check if input is a file path or an image array
    if isinstance(image, str):
        img = cv2.imread(image)
    else:
        img = image

    if img is None:
        print("Error: Could not load image.")
        return [], []

    results = model(img)
    logo_regions = []
    bounding_boxes = []

    if save_crop and not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for idx, box in enumerate(results[0].boxes):
        xyxy = box.xyxy[0].tolist()
        x1, y1, x2, y2 = map(int, xyxy)
        cropped_logo = img[y1:y2, x1:x2]  # extract detected region

        if save_crop and cropped_logo.size > 0:
            cropped_logo_path = os.path.join(output_dir, f"cropped_logo_{idx}.jpg")
            cv2.imwrite(cropped_logo_path, cropped_logo)
            print(f"Logo {idx} saved: {cropped_logo_path}")

        if cropped_logo.size > 0:
            logo_regions.append(cropped_logo)
            bounding_boxes.append((x1, y1, x2, y2))
            print(f"Logo {idx} detected at coordinates: ({x1}, {y1}) -> ({x2}, {y2})")

    return logo_regions, bounding_boxes

# %%
def process_video(input_video_path, output_video_path, frame_skip=5):
    # resnet size = 2048
    # clip size = 512
    # beit size = 768
    embedding_dim = 768 # Size for BEIT
    faiss_index = faiss.IndexFlatL2(embedding_dim)
    logo_id_counter = 0 # How many unique logos we've seen
    logo_id_map = {}  # maps FAISS index to logo ID
    logo_appearance_counts = defaultdict(int) # How many times a unique logo has appeared
    
    cap = cv2.VideoCapture(input_video_path)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    frame_idx = 0
    save_frame = False

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break  # stop if video ends

        if frame_idx % frame_skip == 0:  # process every 5th frame
            print(f"Processing frame {frame_idx}")

            # extract detected logos from the current frame
            input_logos, input_bboxes = extract_logo_regions(frame, save_crop=False)

            # draw a bounding box around each detected logo
            for input_logo, bbox in zip(input_logos, input_bboxes):
                embedding = embed_extract.get_embedding(input_logo, model_name='beit') # Get the embedding of the frame
                faiss.normalize_L2(embedding) # normalize the embedding. Works really well with FAISS

                if faiss_index.ntotal == 0: # First entry into FAISS
                    faiss_index.add(np.array(embedding)) # Get embedding
                    logo_id_map[0] = logo_id_counter # First unique logo
                    logo_appearance_counts[logo_id_counter] += 1 # increment the unique logo
                    logo_id_counter += 1 # Go to next unique ID
                    assigned_id = logo_id_counter - 1 # current unique ID
                    save_frame = True
                else:
                    # Get the L2 distance and index 
                    D, I = faiss_index.search(np.array(embedding), k=1)
                    print("Distance:", D[0][0])
                    # Lower the distance, the better
                    if D[0][0] < 0.5:  # If a distance is above a 0.5, then the logo hasnt been seen
                        print("INDEX ALREADY EXISTS")
                        assigned_id = logo_id_map[I[0][0]]
                        logo_appearance_counts[assigned_id] += 1 # increase the amount of times weve seen this logo
                        save_frame = False
                    else:                        
                        print("ADDING NEW INDEX") # Create a new index into FAISS
                        faiss_index.add(np.array(embedding)) # Add a new index (embedding)
                        logo_id_map[faiss_index.ntotal - 1] = logo_id_counter # Assign the new index to a logo_id
                        logo_appearance_counts[logo_id_counter] += 1 # increment how many times weve seen this unique ID
                        assigned_id = logo_id_counter # current assigned ID
                        logo_id_counter += 1 # Go to the next unique ID
                        save_frame = True
                    
                x1, y1, x2, y2 = bbox
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 255, 255), 5)
                cv2.putText(frame, f"ID: {assigned_id}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (77, 33, 191), 2)

                if save_frame:
                    save_dir = "new_logo_frames"
                    os.makedirs(save_dir, exist_ok=True)
                    save_path = os.path.join(save_dir, f"frame_{frame_idx}_logo_{logo_id_counter}.jpg")
                    cv2.imwrite(save_path, frame)


        out.write(frame)  # write processed frame to output

        frame_idx += 1 # next frame

    cap.release()
    out.release()
    print(f"Processed video saved as {output_video_path}")

    for faiss_idx, counter in logo_id_map.items():
        print(f'{faiss_idx} appeared approx {logo_appearance_counts[counter] * 5} times')

# %%
input_video_path = "starbucks_video.mp4"  # path to input video
output_video_path = "output_video.mp4"  # output processed video

process_video(input_video_path, output_video_path)
# Out:
# Processing frame 0
#
# 0: 384x640 1 logo, 113.0ms
# Speed: 3.8ms preprocess, 113.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1128, 503) -> (1345, 654)
# Processing frame 5
#
# 0: 384x640 1 logo, 89.4ms
# Speed: 3.6ms preprocess, 89.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1129, 504) -> (1343, 654)
# Distance: 0.042679153
# INDEX ALREADY EXISTS
# Processing frame 10
#
# 0: 384x640 1 logo, 105.4ms
# Speed: 3.2ms preprocess, 105.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1129, 503) -> (1342, 653)
# Distance: 0.046831667
# INDEX ALREADY EXISTS
# Processing frame 15
#
# 0: 384x640 1 logo, 92.1ms
# Speed: 2.9ms preprocess, 92.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1128, 503) -> (1341, 653)
# Distance: 0.047004372
# INDEX ALREADY EXISTS
# Processing frame 20
#
# 0: 384x640 1 logo, 90.2ms
# Speed: 3.1ms preprocess, 90.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1128, 502) -> (1341, 653)
# Distance: 0.05419085
# INDEX ALREADY EXISTS
# Processing frame 25
#
# 0: 384x640 1 logo, 103.9ms
# Speed: 3.1ms preprocess, 103.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1127, 503) -> (1339, 652)
# Distance: 0.044292867
# INDEX ALREADY EXISTS
# Processing frame 30
#
# 0: 384x640 1 logo, 95.4ms
# Speed: 3.1ms preprocess, 95.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1127, 502) -> (1338, 652)
# Distance: 0.037436448
# INDEX ALREADY EXISTS
# Processing frame 35
#
# 0: 384x640 1 logo, 103.7ms
# Speed: 3.1ms preprocess, 103.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1126, 500) -> (1338, 652)
# Distance: 0.06184658
# INDEX ALREADY EXISTS
# Processing frame 40
#
# 0: 384x640 1 logo, 103.0ms
# Speed: 3.7ms preprocess, 103.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1125, 500) -> (1337, 652)
# Distance: 0.05239793
# INDEX ALREADY EXISTS
# Processing frame 45
#
# 0: 384x640 1 logo, 94.1ms
# Speed: 3.6ms preprocess, 94.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1119, 497) -> (1337, 653)
# Distance: 0.061766695
# INDEX ALREADY EXISTS
# Processing frame 50
#
# 0: 384x640 1 logo, 94.6ms
# Speed: 3.4ms preprocess, 94.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1123, 496) -> (1337, 652)
# Distance: 0.066848785
# INDEX ALREADY EXISTS
# Processing frame 55
#
# 0: 384x640 1 logo, 107.0ms
# Speed: 2.9ms preprocess, 107.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1117, 491) -> (1338, 653)
# Distance: 0.09613074
# INDEX ALREADY EXISTS
# Processing frame 60
#
# 0: 384x640 1 logo, 110.0ms
# Speed: 3.0ms preprocess, 110.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1116, 491) -> (1337, 654)
# Distance: 0.1200932
# INDEX ALREADY EXISTS
# Processing frame 65
#
# 0: 384x640 1 logo, 99.7ms
# Speed: 3.1ms preprocess, 99.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1118, 488) -> (1336, 653)
# Distance: 0.14378333
# INDEX ALREADY EXISTS
# Processing frame 70
#
# 0: 384x640 1 logo, 92.8ms
# Speed: 3.0ms preprocess, 92.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1118, 488) -> (1336, 652)
# Distance: 0.13288078
# INDEX ALREADY EXISTS
# Processing frame 75
#
# 0: 384x640 1 logo, 94.2ms
# Speed: 3.2ms preprocess, 94.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1117, 487) -> (1333, 652)
# Distance: 0.11800193
# INDEX ALREADY EXISTS
# Processing frame 80
#
# 0: 384x640 1 logo, 94.2ms
# Speed: 2.9ms preprocess, 94.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1117, 487) -> (1334, 653)
# Distance: 0.14170876
# INDEX ALREADY EXISTS
# Processing frame 85
#
# 0: 384x640 1 logo, 90.6ms
# Speed: 2.9ms preprocess, 90.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1115, 485) -> (1332, 654)
# Distance: 0.16626191
# INDEX ALREADY EXISTS
# Processing frame 90
#
# 0: 384x640 1 logo, 88.5ms
# Speed: 3.2ms preprocess, 88.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1115, 486) -> (1331, 654)
# Distance: 0.16588783
# INDEX ALREADY EXISTS
# Processing frame 95
#
# 0: 384x640 1 logo, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1113, 490) -> (1329, 654)
# Distance: 0.15537156
# INDEX ALREADY EXISTS
# Processing frame 100
#
# 0: 384x640 1 logo, 86.4ms
# Speed: 3.1ms preprocess, 86.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1112, 488) -> (1329, 654)
# Distance: 0.1862562
# INDEX ALREADY EXISTS
# Processing frame 105
#
# 0: 384x640 1 logo, 86.8ms
# Speed: 3.0ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1106, 486) -> (1330, 654)
# Distance: 0.14225152
# INDEX ALREADY EXISTS
# Processing frame 110
#
# 0: 384x640 1 logo, 86.2ms
# Speed: 3.0ms preprocess, 86.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1105, 486) -> (1329, 654)
# Distance: 0.16964343
# INDEX ALREADY EXISTS
# Processing frame 115
#
# 0: 384x640 1 logo, 88.7ms
# Speed: 3.1ms preprocess, 88.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (1100, 480) -> (1328, 663)
# Distance: 0.18098052
# INDEX ALREADY EXISTS
# Processing frame 120
#
# 0: 384x640 (no detections), 93.2ms
# Speed: 3.3ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 125
#
# 0: 384x640 (no detections), 93.4ms
# Speed: 3.3ms preprocess, 93.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 130
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 3.4ms preprocess, 99.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 135
#
# 0: 384x640 (no detections), 98.0ms
# Speed: 3.6ms preprocess, 98.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 140
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 2.9ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 145
#
# 0: 384x640 (no detections), 86.4ms
# Speed: 2.6ms preprocess, 86.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 150
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 3.1ms preprocess, 87.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 155
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 3.2ms preprocess, 84.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 160
#
# 0: 384x640 (no detections), 95.4ms
# Speed: 3.0ms preprocess, 95.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 165
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 3.2ms preprocess, 95.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 170
#
# 0: 384x640 (no detections), 92.1ms
# Speed: 3.2ms preprocess, 92.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 175
#
# 0: 384x640 (no detections), 92.6ms
# Speed: 2.9ms preprocess, 92.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 180
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 2.9ms preprocess, 75.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 185
#
# 0: 384x640 (no detections), 82.2ms
# Speed: 2.5ms preprocess, 82.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 190
#
# 0: 384x640 (no detections), 81.6ms
# Speed: 3.7ms preprocess, 81.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 195
#
# 0: 384x640 (no detections), 92.4ms
# Speed: 2.7ms preprocess, 92.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 200
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 3.1ms preprocess, 100.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 205
#
# 0: 384x640 (no detections), 84.1ms
# Speed: 2.8ms preprocess, 84.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 210
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 3.4ms preprocess, 83.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 215
#
# 0: 384x640 (no detections), 93.3ms
# Speed: 3.1ms preprocess, 93.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 220
#
# 0: 384x640 (no detections), 91.0ms
# Speed: 3.6ms preprocess, 91.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 225
#
# 0: 384x640 (no detections), 95.2ms
# Speed: 3.0ms preprocess, 95.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 230
#
# 0: 384x640 (no detections), 80.9ms
# Speed: 2.7ms preprocess, 80.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 235
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 240
#
# 0: 384x640 (no detections), 82.2ms
# Speed: 3.2ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 245
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 2.8ms preprocess, 81.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 250
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 2.9ms preprocess, 83.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 255
#
# 0: 384x640 (no detections), 94.2ms
# Speed: 2.9ms preprocess, 94.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 260
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 3.1ms preprocess, 90.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 265
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 2.9ms preprocess, 81.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 270
#
# 0: 384x640 (no detections), 90.6ms
# Speed: 2.9ms preprocess, 90.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 275
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 3.4ms preprocess, 88.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 280
#
# 0: 384x640 (no detections), 82.8ms
# Speed: 2.9ms preprocess, 82.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 285
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 3.1ms preprocess, 83.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 290
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.8ms preprocess, 87.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 295
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 3.1ms preprocess, 82.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 300
#
# 0: 384x640 (no detections), 87.6ms
# Speed: 3.1ms preprocess, 87.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 305
#
# 0: 384x640 (no detections), 95.1ms
# Speed: 3.2ms preprocess, 95.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 310
#
# 0: 384x640 (no detections), 91.0ms
# Speed: 3.2ms preprocess, 91.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 315
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 320
#
# 0: 384x640 (no detections), 90.2ms
# Speed: 3.2ms preprocess, 90.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 325
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 3.1ms preprocess, 83.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 330
#
# 0: 384x640 (no detections), 95.1ms
# Speed: 2.9ms preprocess, 95.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 335
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 3.2ms preprocess, 90.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 340
#
# 0: 384x640 (no detections), 85.2ms
# Speed: 3.3ms preprocess, 85.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 345
#
# 0: 384x640 (no detections), 92.5ms
# Speed: 2.9ms preprocess, 92.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 350
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 3.2ms preprocess, 85.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 355
#
# 0: 384x640 (no detections), 85.8ms
# Speed: 5.8ms preprocess, 85.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 360
#
# 0: 384x640 (no detections), 89.0ms
# Speed: 2.9ms preprocess, 89.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 365
#
# 0: 384x640 (no detections), 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 370
#
# 0: 384x640 (no detections), 91.8ms
# Speed: 3.4ms preprocess, 91.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 375
#
# 0: 384x640 1 logo, 94.1ms
# Speed: 2.8ms preprocess, 94.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (810, 432) -> (952, 552)
# Distance: 1.6421869
# ADDING NEW INDEX
# Processing frame 380
#
# 0: 384x640 (no detections), 94.4ms
# Speed: 3.1ms preprocess, 94.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 385
#
# 0: 384x640 (no detections), 93.0ms
# Speed: 3.0ms preprocess, 93.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 390
#
# 0: 384x640 1 logo, 85.2ms
# Speed: 3.7ms preprocess, 85.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (815, 440) -> (951, 552)
# Distance: 0.98370034
# ADDING NEW INDEX
# Processing frame 395
#
# 0: 384x640 (no detections), 93.9ms
# Speed: 3.2ms preprocess, 93.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 400
#
# 0: 384x640 (no detections), 103.8ms
# Speed: 3.1ms preprocess, 103.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 405
#
# 0: 384x640 (no detections), 97.2ms
# Speed: 3.3ms preprocess, 97.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 410
#
# 0: 384x640 (no detections), 90.9ms
# Speed: 3.0ms preprocess, 90.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 415
#
# 0: 384x640 (no detections), 89.3ms
# Speed: 2.9ms preprocess, 89.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 420
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 3.1ms preprocess, 83.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 425
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 2.8ms preprocess, 84.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 430
#
# 0: 384x640 (no detections), 82.4ms
# Speed: 2.8ms preprocess, 82.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 435
#
# 0: 384x640 (no detections), 77.9ms
# Speed: 2.9ms preprocess, 77.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 440
#
# 0: 384x640 (no detections), 82.1ms
# Speed: 2.5ms preprocess, 82.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 445
#
# 0: 384x640 (no detections), 78.5ms
# Speed: 2.8ms preprocess, 78.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 450
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 2.7ms preprocess, 74.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 455
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 8.0ms preprocess, 100.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 460
#
# 0: 384x640 1 logo, 97.9ms
# Speed: 3.2ms preprocess, 97.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (721, 452) -> (1301, 709)
# Distance: 1.5506434
# ADDING NEW INDEX
# Processing frame 465
#
# 0: 384x640 (no detections), 94.2ms
# Speed: 3.2ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 470
#
# 0: 384x640 (no detections), 86.6ms
# Speed: 3.1ms preprocess, 86.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 475
#
# 0: 384x640 (no detections), 84.9ms
# Speed: 3.2ms preprocess, 84.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 480
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 3.0ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 485
#
# 0: 384x640 (no detections), 81.4ms
# Speed: 3.1ms preprocess, 81.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 490
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 3.4ms preprocess, 82.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 495
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 3.2ms preprocess, 88.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 500
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 2.9ms preprocess, 86.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 505
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 3.0ms preprocess, 90.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 510
#
# 0: 384x640 (no detections), 83.1ms
# Speed: 3.3ms preprocess, 83.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 515
#
# 0: 384x640 (no detections), 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 520
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 3.2ms preprocess, 90.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 525
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 530
#
# 0: 384x640 (no detections), 85.4ms
# Speed: 2.9ms preprocess, 85.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 535
#
# 0: 384x640 (no detections), 96.5ms
# Speed: 2.9ms preprocess, 96.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 540
#
# 0: 384x640 (no detections), 80.2ms
# Speed: 2.9ms preprocess, 80.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 545
#
# 0: 384x640 (no detections), 78.6ms
# Speed: 2.8ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 550
#
# 0: 384x640 (no detections), 87.0ms
# Speed: 2.9ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 555
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 2.7ms preprocess, 87.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 560
#
# 0: 384x640 (no detections), 82.6ms
# Speed: 2.7ms preprocess, 82.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 565
#
# 0: 384x640 (no detections), 79.7ms
# Speed: 2.9ms preprocess, 79.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 570
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 2.7ms preprocess, 86.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 575
#
# 0: 384x640 (no detections), 93.4ms
# Speed: 2.9ms preprocess, 93.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 580
#
# 0: 384x640 (no detections), 106.6ms
# Speed: 3.4ms preprocess, 106.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 585
#
# 0: 384x640 (no detections), 94.5ms
# Speed: 3.1ms preprocess, 94.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 590
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 595
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 2.6ms preprocess, 82.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 600
#
# 0: 384x640 (no detections), 88.6ms
# Speed: 2.9ms preprocess, 88.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 605
#
# 0: 384x640 (no detections), 85.4ms
# Speed: 3.1ms preprocess, 85.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 610
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 3.1ms preprocess, 82.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 615
#
# 0: 384x640 (no detections), 81.3ms
# Speed: 3.1ms preprocess, 81.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 620
#
# 0: 384x640 1 logo, 82.1ms
# Speed: 2.9ms preprocess, 82.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (849, 104) -> (1044, 385)
# Distance: 1.4413095
# ADDING NEW INDEX
# Processing frame 625
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 3.3ms preprocess, 90.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 630
#
# 0: 384x640 (no detections), 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 635
#
# 0: 384x640 (no detections), 84.0ms
# Speed: 3.6ms preprocess, 84.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 640
#
# 0: 384x640 (no detections), 77.6ms
# Speed: 2.8ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 645
#
# 0: 384x640 (no detections), 80.5ms
# Speed: 2.9ms preprocess, 80.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 650
#
# 0: 384x640 (no detections), 82.3ms
# Speed: 2.5ms preprocess, 82.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 655
#
# 0: 384x640 (no detections), 84.3ms
# Speed: 2.8ms preprocess, 84.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 660
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 2.9ms preprocess, 79.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 665
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 2.5ms preprocess, 88.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 670
#
# 0: 384x640 (no detections), 76.1ms
# Speed: 2.6ms preprocess, 76.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 675
#
# 0: 384x640 (no detections), 86.9ms
# Speed: 3.0ms preprocess, 86.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 680
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 2.6ms preprocess, 86.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 685
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 2.8ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 690
#
# 0: 384x640 (no detections), 82.9ms
# Speed: 2.8ms preprocess, 82.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 695
#
# 0: 384x640 (no detections), 90.8ms
# Speed: 3.0ms preprocess, 90.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 700
#
# 0: 384x640 (no detections), 82.8ms
# Speed: 2.8ms preprocess, 82.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 705
#
# 0: 384x640 (no detections), 88.7ms
# Speed: 3.2ms preprocess, 88.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 710
#
# 0: 384x640 (no detections), 146.4ms
# Speed: 2.7ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 715
#
# 0: 384x640 (no detections), 83.9ms
# Speed: 3.1ms preprocess, 83.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 720
#
# 0: 384x640 (no detections), 83.7ms
# Speed: 2.8ms preprocess, 83.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 725
#
# 0: 384x640 (no detections), 84.3ms
# Speed: 2.8ms preprocess, 84.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 730
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 2.7ms preprocess, 79.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 735
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 2.9ms preprocess, 89.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 740
#
# 0: 384x640 (no detections), 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 745
#
# 0: 384x640 (no detections), 82.5ms
# Speed: 2.7ms preprocess, 82.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 750
#
# 0: 384x640 (no detections), 81.7ms
# Speed: 3.1ms preprocess, 81.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 755
#
# 0: 384x640 (no detections), 80.3ms
# Speed: 2.7ms preprocess, 80.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 760
#
# 0: 384x640 (no detections), 79.1ms
# Speed: 2.8ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 765
#
# 0: 384x640 (no detections), 77.8ms
# Speed: 2.8ms preprocess, 77.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 770
#
# 0: 384x640 (no detections), 78.4ms
# Speed: 2.8ms preprocess, 78.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 775
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 2.8ms preprocess, 81.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 780
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 2.8ms preprocess, 81.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 785
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 3.6ms preprocess, 98.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 790
#
# 0: 384x640 (no detections), 97.2ms
# Speed: 3.4ms preprocess, 97.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 795
#
# 0: 384x640 (no detections), 109.2ms
# Speed: 4.0ms preprocess, 109.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 800
#
# 0: 384x640 (no detections), 97.4ms
# Speed: 3.1ms preprocess, 97.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 805
#
# 0: 384x640 (no detections), 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 810
#
# 0: 384x640 (no detections), 94.5ms
# Speed: 3.1ms preprocess, 94.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 815
#
# 0: 384x640 (no detections), 93.3ms
# Speed: 2.7ms preprocess, 93.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 820
#
# 0: 384x640 (no detections), 101.6ms
# Speed: 3.3ms preprocess, 101.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 825
#
# 0: 384x640 (no detections), 92.7ms
# Speed: 2.9ms preprocess, 92.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 830
#
# 0: 384x640 (no detections), 91.8ms
# Speed: 2.8ms preprocess, 91.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 835
#
# 0: 384x640 (no detections), 92.5ms
# Speed: 3.3ms preprocess, 92.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 840
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 2.9ms preprocess, 83.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 845
#
# 0: 384x640 (no detections), 92.9ms
# Speed: 2.9ms preprocess, 92.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 850
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 2.7ms preprocess, 79.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 855
#
# 0: 384x640 (no detections), 91.4ms
# Speed: 2.6ms preprocess, 91.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 860
#
# 0: 384x640 (no detections), 97.5ms
# Speed: 2.5ms preprocess, 97.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 865
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 2.6ms preprocess, 87.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 870
#
# 0: 384x640 (no detections), 79.9ms
# Speed: 2.8ms preprocess, 79.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 875
#
# 0: 384x640 (no detections), 84.3ms
# Speed: 3.2ms preprocess, 84.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 880
#
# 0: 384x640 (no detections), 75.9ms
# Speed: 2.6ms preprocess, 75.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 885
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 2.9ms preprocess, 80.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 890
#
# 0: 384x640 (no detections), 77.4ms
# Speed: 2.9ms preprocess, 77.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 895
#
# 0: 384x640 1 logo, 81.7ms
# Speed: 2.8ms preprocess, 81.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (579, 164) -> (1916, 902)
# Distance: 1.6807227
# ADDING NEW INDEX
# Processing frame 900
#
# 0: 384x640 1 logo, 89.1ms
# Speed: 3.2ms preprocess, 89.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (577, 162) -> (1916, 903)
# Distance: 0.010354889
# INDEX ALREADY EXISTS
# Processing frame 905
#
# 0: 384x640 1 logo, 171.3ms
# Speed: 3.0ms preprocess, 171.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (572, 163) -> (1915, 900)
# Distance: 0.033189964
# INDEX ALREADY EXISTS
# Processing frame 910
#
# 0: 384x640 1 logo, 83.7ms
# Speed: 3.0ms preprocess, 83.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (566, 161) -> (1916, 899)
# Distance: 0.059065055
# INDEX ALREADY EXISTS
# Processing frame 915
#
# 0: 384x640 1 logo, 90.4ms
# Speed: 2.9ms preprocess, 90.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (547, 161) -> (1916, 896)
# Distance: 0.08807324
# INDEX ALREADY EXISTS
# Processing frame 920
#
# 0: 384x640 1 logo, 91.5ms
# Speed: 2.9ms preprocess, 91.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (522, 161) -> (1916, 893)
# Distance: 0.15455174
# INDEX ALREADY EXISTS
# Processing frame 925
#
# 0: 384x640 1 logo, 91.3ms
# Speed: 2.9ms preprocess, 91.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (498, 160) -> (1917, 892)
# Distance: 0.21498156
# INDEX ALREADY EXISTS
# Processing frame 930
#
# 0: 384x640 1 logo, 88.3ms
# Speed: 3.1ms preprocess, 88.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (484, 161) -> (1917, 890)
# Distance: 0.2013057
# INDEX ALREADY EXISTS
# Processing frame 935
#
# 0: 384x640 1 logo, 105.6ms
# Speed: 3.2ms preprocess, 105.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (485, 161) -> (1916, 891)
# Distance: 0.23135415
# INDEX ALREADY EXISTS
# Processing frame 940
#
# 0: 384x640 1 logo, 87.2ms
# Speed: 3.2ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (488, 161) -> (1916, 890)
# Distance: 0.290031
# INDEX ALREADY EXISTS
# Processing frame 945
#
# 0: 384x640 1 logo, 95.4ms
# Speed: 2.9ms preprocess, 95.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (446, 163) -> (1916, 889)
# Distance: 0.21482041
# INDEX ALREADY EXISTS
# Processing frame 950
#
# 0: 384x640 1 logo, 92.6ms
# Speed: 3.2ms preprocess, 92.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (456, 163) -> (1916, 888)
# Distance: 0.21140093
# INDEX ALREADY EXISTS
# Processing frame 955
#
# 0: 384x640 (no detections), 91.6ms
# Speed: 2.9ms preprocess, 91.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 960
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 2.7ms preprocess, 85.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 965
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 970
#
# 0: 384x640 (no detections), 93.5ms
# Speed: 3.2ms preprocess, 93.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 975
#
# 0: 384x640 (no detections), 89.9ms
# Speed: 2.9ms preprocess, 89.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 980
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 3.1ms preprocess, 89.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 985
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 2.9ms preprocess, 96.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 990
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 3.5ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 995
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 3.0ms preprocess, 84.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1000
#
# 0: 384x640 (no detections), 82.9ms
# Speed: 2.9ms preprocess, 82.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1005
#
# 0: 384x640 (no detections), 77.1ms
# Speed: 2.4ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1010
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 2.6ms preprocess, 82.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1015
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 2.7ms preprocess, 88.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1020
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 2.9ms preprocess, 85.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1025
#
# 0: 384x640 (no detections), 88.6ms
# Speed: 2.7ms preprocess, 88.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1030
#
# 0: 384x640 (no detections), 86.1ms
# Speed: 3.0ms preprocess, 86.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1035
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 2.9ms preprocess, 86.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1040
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1045
#
# 0: 384x640 (no detections), 96.2ms
# Speed: 3.0ms preprocess, 96.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1050
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 2.9ms preprocess, 85.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1055
#
# 0: 384x640 (no detections), 145.9ms
# Speed: 14.5ms preprocess, 145.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1060
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 2.8ms preprocess, 88.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1065
#
# 0: 384x640 (no detections), 102.8ms
# Speed: 3.2ms preprocess, 102.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1070
#
# 0: 384x640 (no detections), 99.4ms
# Speed: 2.7ms preprocess, 99.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1075
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 2.7ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1080
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 2.8ms preprocess, 89.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1085
#
# 0: 384x640 (no detections), 92.3ms
# Speed: 3.3ms preprocess, 92.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1090
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 2.7ms preprocess, 86.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1095
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 3.3ms preprocess, 89.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1100
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 2.7ms preprocess, 95.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1105
#
# 0: 384x640 (no detections), 96.7ms
# Speed: 2.8ms preprocess, 96.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1110
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1115
#
# 0: 384x640 (no detections), 93.3ms
# Speed: 2.9ms preprocess, 93.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1120
#
# 0: 384x640 (no detections), 94.3ms
# Speed: 2.9ms preprocess, 94.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1125
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 2.8ms preprocess, 98.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1130
#
# 0: 384x640 (no detections), 85.8ms
# Speed: 2.9ms preprocess, 85.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1135
#
# 0: 384x640 (no detections), 86.4ms
# Speed: 2.9ms preprocess, 86.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1140
#
# 0: 384x640 (no detections), 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1145
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 3.4ms preprocess, 86.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1150
#
# 0: 384x640 1 logo, 80.8ms
# Speed: 3.3ms preprocess, 80.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (303, 180) -> (1536, 1080)
# Distance: 1.6231214
# ADDING NEW INDEX
# Processing frame 1155
#
# 0: 384x640 1 logo, 92.7ms
# Speed: 3.2ms preprocess, 92.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (305, 180) -> (1537, 1080)
# Distance: 0.024542488
# INDEX ALREADY EXISTS
# Processing frame 1160
#
# 0: 384x640 1 logo, 96.4ms
# Speed: 3.0ms preprocess, 96.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (304, 179) -> (1535, 1080)
# Distance: 0.031188834
# INDEX ALREADY EXISTS
# Processing frame 1165
#
# 0: 384x640 1 logo, 97.0ms
# Speed: 2.9ms preprocess, 97.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (307, 178) -> (1537, 1080)
# Distance: 0.0475234
# INDEX ALREADY EXISTS
# Processing frame 1170
#
# 0: 384x640 1 logo, 95.3ms
# Speed: 3.0ms preprocess, 95.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (308, 181) -> (1536, 1080)
# Distance: 0.050265163
# INDEX ALREADY EXISTS
# Processing frame 1175
#
# 0: 384x640 1 logo, 93.4ms
# Speed: 3.2ms preprocess, 93.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (305, 180) -> (1537, 1080)
# Distance: 0.04690308
# INDEX ALREADY EXISTS
# Processing frame 1180
#
# 0: 384x640 1 logo, 95.4ms
# Speed: 3.3ms preprocess, 95.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (305, 181) -> (1536, 1080)
# Distance: 0.11308475
# INDEX ALREADY EXISTS
# Processing frame 1185
#
# 0: 384x640 1 logo, 94.1ms
# Speed: 3.2ms preprocess, 94.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (307, 179) -> (1537, 1080)
# Distance: 0.03753918
# INDEX ALREADY EXISTS
# Processing frame 1190
#
# 0: 384x640 1 logo, 95.1ms
# Speed: 3.0ms preprocess, 95.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (310, 181) -> (1535, 1080)
# Distance: 0.0503997
# INDEX ALREADY EXISTS
# Processing frame 1195
#
# 0: 384x640 1 logo, 95.6ms
# Speed: 3.1ms preprocess, 95.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (308, 180) -> (1537, 1080)
# Distance: 0.08203184
# INDEX ALREADY EXISTS
# Processing frame 1200
#
# 0: 384x640 1 logo, 93.7ms
# Speed: 2.9ms preprocess, 93.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (304, 179) -> (1540, 1080)
# Distance: 0.10442865
# INDEX ALREADY EXISTS
# Processing frame 1205
#
# 0: 384x640 1 logo, 89.9ms
# Speed: 3.1ms preprocess, 89.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (282, 178) -> (1542, 1080)
# Distance: 0.057126716
# INDEX ALREADY EXISTS
# Processing frame 1210
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 3.1ms preprocess, 90.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1215
#
# 0: 384x640 (no detections), 96.8ms
# Speed: 3.5ms preprocess, 96.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1220
#
# 0: 384x640 (no detections), 86.6ms
# Speed: 2.9ms preprocess, 86.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1225
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 2.7ms preprocess, 78.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1230
#
# 0: 384x640 (no detections), 78.1ms
# Speed: 3.2ms preprocess, 78.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1235
#
# 0: 384x640 (no detections), 82.4ms
# Speed: 2.9ms preprocess, 82.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1240
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 2.8ms preprocess, 83.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1245
#
# 0: 384x640 (no detections), 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1250
#
# 0: 384x640 (no detections), 94.7ms
# Speed: 2.6ms preprocess, 94.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1255
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 2.8ms preprocess, 89.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1260
#
# 0: 384x640 (no detections), 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1265
#
# 0: 384x640 (no detections), 83.9ms
# Speed: 2.7ms preprocess, 83.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1270
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.9ms preprocess, 87.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1275
#
# 0: 384x640 (no detections), 99.0ms
# Speed: 2.6ms preprocess, 99.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1280
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 3.4ms preprocess, 90.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1285
#
# 0: 384x640 (no detections), 86.4ms
# Speed: 3.3ms preprocess, 86.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1290
#
# 0: 384x640 (no detections), 94.2ms
# Speed: 2.6ms preprocess, 94.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1295
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 3.3ms preprocess, 84.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1300
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 2.7ms preprocess, 89.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1305
#
# 0: 384x640 (no detections), 95.9ms
# Speed: 2.8ms preprocess, 95.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1310
#
# 0: 384x640 (no detections), 142.3ms
# Speed: 3.3ms preprocess, 142.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1315
#
# 0: 384x640 (no detections), 88.3ms
# Speed: 2.8ms preprocess, 88.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1320
#
# 0: 384x640 (no detections), 84.9ms
# Speed: 2.9ms preprocess, 84.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1325
#
# 0: 384x640 1 logo, 87.5ms
# Speed: 3.9ms preprocess, 87.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (232, 0) -> (1903, 991)
# Distance: 1.3974853
# ADDING NEW INDEX
# Processing frame 1330
#
# 0: 384x640 1 logo, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (247, 9) -> (1907, 975)
# Distance: 0.143127
# INDEX ALREADY EXISTS
# Processing frame 1335
#
# 0: 384x640 1 logo, 95.4ms
# Speed: 3.0ms preprocess, 95.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (268, 12) -> (1905, 976)
# Distance: 0.27761674
# INDEX ALREADY EXISTS
# Processing frame 1340
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 2.9ms preprocess, 98.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1345
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 2.9ms preprocess, 88.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1350
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 3.0ms preprocess, 87.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1355
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 2.8ms preprocess, 87.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1360
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 3.1ms preprocess, 86.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1365
#
# 0: 384x640 1 logo, 90.5ms
# Speed: 2.8ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (71, 0) -> (1917, 982)
# Distance: 0.26694298
# INDEX ALREADY EXISTS
# Processing frame 1370
#
# 0: 384x640 1 logo, 83.8ms
# Speed: 3.1ms preprocess, 83.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (57, 0) -> (1917, 971)
# Distance: 0.24086101
# INDEX ALREADY EXISTS
# Processing frame 1375
#
# 0: 384x640 1 logo, 94.6ms
# Speed: 3.3ms preprocess, 94.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logo 0 detected at coordinates: (83, 0) -> (1917, 962)
# Distance: 0.23543634
# INDEX ALREADY EXISTS
# Processing frame 1380
#
# 0: 384x640 (no detections), 89.0ms
# Speed: 2.9ms preprocess, 89.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1385
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 2.9ms preprocess, 90.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1390
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 3.2ms preprocess, 87.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1395
#
# 0: 384x640 (no detections), 98.6ms
# Speed: 2.9ms preprocess, 98.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1400
#
# 0: 384x640 (no detections), 88.2ms
# Speed: 3.0ms preprocess, 88.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1405
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 2.8ms preprocess, 88.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1410
#
# 0: 384x640 (no detections), 93.9ms
# Speed: 2.7ms preprocess, 93.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1415
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 3.2ms preprocess, 88.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1420
#
# 0: 384x640 (no detections), 200.9ms
# Speed: 2.9ms preprocess, 200.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1425
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 2.9ms preprocess, 81.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1430
#
# 0: 384x640 (no detections), 82.1ms
# Speed: 2.7ms preprocess, 82.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1435
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 2.9ms preprocess, 90.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1440
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 3.1ms preprocess, 84.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1445
#
# 0: 384x640 (no detections), 81.6ms
# Speed: 2.8ms preprocess, 81.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1450
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.8ms preprocess, 87.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1455
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 3.1ms preprocess, 90.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1460
#
# 0: 384x640 (no detections), 91.1ms
# Speed: 2.8ms preprocess, 91.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1465
#
# 0: 384x640 (no detections), 83.2ms
# Speed: 2.9ms preprocess, 83.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1470
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 2.8ms preprocess, 86.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1475
#
# 0: 384x640 (no detections), 92.1ms
# Speed: 2.8ms preprocess, 92.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1480
#
# 0: 384x640 (no detections), 97.7ms
# Speed: 3.1ms preprocess, 97.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1485
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1490
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 3.1ms preprocess, 83.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1495
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 2.8ms preprocess, 84.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1500
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 2.8ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1505
#
# 0: 384x640 (no detections), 82.5ms
# Speed: 2.6ms preprocess, 82.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1510
#
# 0: 384x640 (no detections), 85.1ms
# Speed: 2.8ms preprocess, 85.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1515
#
# 0: 384x640 (no detections), 84.3ms
# Speed: 2.8ms preprocess, 84.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1520
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 2.8ms preprocess, 85.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1525
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 2.8ms preprocess, 81.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1530
#
# 0: 384x640 (no detections), 114.3ms
# Speed: 3.3ms preprocess, 114.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1535
#
# 0: 384x640 (no detections), 88.5ms
# Speed: 2.7ms preprocess, 88.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1540
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 2.9ms preprocess, 84.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1545
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 2.8ms preprocess, 79.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1550
#
# 0: 384x640 (no detections), 81.3ms
# Speed: 2.8ms preprocess, 81.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1555
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 2.7ms preprocess, 88.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1560
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 2.8ms preprocess, 84.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1565
#
# 0: 384x640 (no detections), 80.1ms
# Speed: 2.7ms preprocess, 80.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1570
#
# 0: 384x640 (no detections), 79.9ms
# Speed: 3.0ms preprocess, 79.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1575
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 3.1ms preprocess, 87.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1580
#
# 0: 384x640 (no detections), 90.8ms
# Speed: 3.2ms preprocess, 90.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1585
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 3.2ms preprocess, 88.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1590
#
# 0: 384x640 (no detections), 89.0ms
# Speed: 3.2ms preprocess, 89.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1595
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 2.9ms preprocess, 86.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1600
#
# 0: 384x640 (no detections), 80.0ms
# Speed: 2.7ms preprocess, 80.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1605
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 3.2ms preprocess, 86.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1610
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 2.9ms preprocess, 80.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1615
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.7ms preprocess, 87.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1620
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 3.0ms preprocess, 90.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1625
#
# 0: 384x640 (no detections), 96.6ms
# Speed: 3.0ms preprocess, 96.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1630
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 2.9ms preprocess, 89.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1635
#
# 0: 384x640 (no detections), 191.2ms
# Speed: 2.9ms preprocess, 191.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1640
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 3.1ms preprocess, 87.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1645
#
# 0: 384x640 (no detections), 88.5ms
# Speed: 2.9ms preprocess, 88.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1650
#
# 0: 384x640 (no detections), 91.4ms
# Speed: 3.1ms preprocess, 91.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1655
#
# 0: 384x640 (no detections), 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1660
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 3.5ms preprocess, 96.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1665
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1670
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 2.8ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1675
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 2.8ms preprocess, 82.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1680
#
# 0: 384x640 (no detections), 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1685
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 2.7ms preprocess, 87.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1690
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 2.6ms preprocess, 89.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1695
#
# 0: 384x640 (no detections), 102.4ms
# Speed: 3.1ms preprocess, 102.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1700
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 3.1ms preprocess, 90.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1705
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 2.5ms preprocess, 86.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1710
#
# 0: 384x640 (no detections), 93.1ms
# Speed: 3.1ms preprocess, 93.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1715
#
# 0: 384x640 (no detections), 82.8ms
# Speed: 2.8ms preprocess, 82.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1720
#
# 0: 384x640 (no detections), 84.2ms
# Speed: 3.1ms preprocess, 84.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1725
#
# 0: 384x640 (no detections), 83.3ms
# Speed: 3.3ms preprocess, 83.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1730
#
# 0: 384x640 (no detections), 95.1ms
# Speed: 3.0ms preprocess, 95.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1735
#
# 0: 384x640 (no detections), 146.7ms
# Speed: 3.9ms preprocess, 146.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1740
#
# 0: 384x640 (no detections), 98.4ms
# Speed: 3.3ms preprocess, 98.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1745
#
# 0: 384x640 (no detections), 92.7ms
# Speed: 3.0ms preprocess, 92.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1750
#
# 0: 384x640 (no detections), 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1755
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 3.1ms preprocess, 89.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1760
#
# 0: 384x640 (no detections), 97.3ms
# Speed: 3.0ms preprocess, 97.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1765
#
# 0: 384x640 (no detections), 92.6ms
# Speed: 2.9ms preprocess, 92.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1770
#
# 0: 384x640 (no detections), 93.1ms
# Speed: 3.5ms preprocess, 93.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1775
#
# 0: 384x640 (no detections), 92.1ms
# Speed: 3.0ms preprocess, 92.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1780
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 3.3ms preprocess, 89.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1785
#
# 0: 384x640 (no detections), 81.2ms
# Speed: 3.3ms preprocess, 81.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1790
#
# 0: 384x640 (no detections), 83.4ms
# Speed: 2.8ms preprocess, 83.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1795
#
# 0: 384x640 (no detections), 79.9ms
# Speed: 2.7ms preprocess, 79.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1800
#
# 0: 384x640 (no detections), 77.1ms
# Speed: 3.0ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1805
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 2.8ms preprocess, 86.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1810
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 3.8ms preprocess, 88.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1815
#
# 0: 384x640 (no detections), 82.5ms
# Speed: 2.8ms preprocess, 82.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame 1820
#
# 0: 384x640 (no detections), 81.7ms
# Speed: 3.2ms preprocess, 81.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved as output_video.mp4
# 0 appeared approx 120 times
# 1 appeared approx 5 times
# 2 appeared approx 5 times
# 3 appeared approx 5 times
# 4 appeared approx 5 times
# 5 appeared approx 60 times
# 6 appeared approx 60 times
# 7 appeared approx 30 times
